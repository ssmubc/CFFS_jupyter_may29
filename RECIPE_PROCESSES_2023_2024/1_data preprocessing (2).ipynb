# %% [markdown]
# ![](ubc_header.png)

# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# #### Sharon Marfatia, CFFS Data Analyst
# ****
#
# ## Part I: Data Preprocessing

# %% [markdown]
# ## Set up and Import Libraries

# %%
#pip install -r requirements.txt

# %%
import numpy as np
import pandas as pd
import pdpipe as pdp
import matplotlib.pyplot as plt
import glob
import os
import csv
from itertools import islice
from decimal import Decimal
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
import openpyxl
import pytest
# Out:
# C:\Users\smvan\anaconda3\lib\site-packages\pdpipe\col_generation.py:12: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Changed the path here, May 2nd 2023
# Set the root path, change the the current working directory into the project folder
path = "C:/Users/smvan/CFFS-S23/CFFS-22-23"
# path = os.getcwd()

# os.chdir is used to change the current directory to the specified path
os.chdir(path)
print(path)
# Out:
# C:/Users/smvan/CFFS-S23/CFFS-22-23

# %%
# Enable reading data table in the scrolling window if you prefer
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ****
#
# ## Load Data Files
#
# ### Set Data File Path

# %%
# Select data file path for the chosen venue and time range where the recipes data stored

# Totem 2019
# filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "Totem 19-20*", "*.oc"))

# Gather 2019
# filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "Gather 19-20*", "*.oc"))

# OK 2019
# filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "OK 19-20*", "*.oc"))

# filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "OK 22-23*", "*.oc"))

filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "OK 23-24 Sep-Dec*", "*.oc"))


filepath_list
# Out:
# ['C:\\Users\\smvan\\CFFS-S23\\CFFS-22-23\\data\\raw\\OK 23-24 Sep-Dec\\OK_Soup.oc']

# %% [markdown]
# ### Import Items List

# %%
# Read items.xml files in the filepath_list and construct a dataframe
ItemId = []
Description = []
CaseQty = []
CaseUOM = []
PakQty = []
PakUOM = []
InventoryGroup = []


# from the items xml file, findtext of CaseQty, CaseUOM, PakQty, PakUOM, and InventoryGroup
# then append it on the lists above

for filepath in filepath_list:
    path = filepath + '/items.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for item in xtree.iterfind('Item'):
            ItemId.append(item.attrib['id'])
            Description.append(item.findtext('Description'))
            CaseQty.append(item.findtext('CaseQty'))
            CaseUOM.append(item.findtext('CaseUOM'))
            PakQty.append(item.findtext('PakQty'))
            PakUOM.append(item.findtext('PakUOM'))
            InventoryGroup.append(item.findtext('InventoryGroup'))

            
# Create a dataframe from the lists created above.
        
Items = pd.DataFrame({'ItemId': ItemId, 'Description': Description, 'CaseQty': CaseQty, 
                      'CaseUOM': CaseUOM, 'PakQty': PakQty, 'PakUOM': PakUOM, 'InventoryGroup': InventoryGroup}
                    )
Items.drop_duplicates(inplace=True)

Items.reset_index(drop=True, inplace=True)

# %%
Items
# Out:
#      ItemId                     Description    CaseQty CaseUOM    PakQty  \
# 0   I-11181                ANISE STAR WHOLE      8.000    each   240.000
# 1    I-4473               AVOCADO (20CT) MX     20.000      CT     1.000
# 2    I-4472                      AVOCADO MX     20.000      CT     1.000
# 3    I-4973             AVOCADO PULP CHUNKY     12.000     bag   454.000
# 4   I-27410        BACON 3MM NATURALLY SMKD      5.000      Kg     1.000
# 5    I-4495             BAK CHOY (60 LBS)US     50.000      lb     1.000
# 90  I-15358   TORTILLA CORN WHTE 6IN EX THN    720.000      ea     1.000
# 91   I-5983               WATER FOR RECIPES      1.000       L     1.000
# 92  I-47530                  WONTON CHICKEN    320.000      ea     1.000
#
#    PakUOM          InventoryGroup
# 0       g                  SPICES
# 1    HEAD                 PRODUCE
# 2      CT                 PRODUCE
# 3       g                 PRODUCE
# 4      Kg                    MEAT
# 5      lb                 PRODUCE
# 6      lb                 PRODUCE
# 7      ml          FOOD - GROCERY
# 8       g                  SPICES
# 9       L          FOOD - GROCERY
# 10     Kg                    MEAT
# 11     Kg                    MEAT
# 12      g                   DAIRY
# 13     lb                 PRODUCE
# 14     lb                 PRODUCE
# 15     CT                 PRODUCE
# 16   HEAD                 PRODUCE
# 17  slice                   DAIRY
# 18  slice                   DAIRY
# 19     Kg                 POULTRY
# 20     Kg                 POULTRY
# 21      g          FOOD - GROCERY
# 22      g                  SPICES
# 23  piece                  SPICES
# 24     oz                  SPICES
# 25     lb                  SPICES
# 26      g                  SPICES
# 27     Kg                 PRODUCE
# 28      L                   DAIRY
# 29     oz                  SPICES
# 30     lb                 PRODUCE
# 31      g          FOOD - GROCERY
# 32     lb                 PRODUCE
# 33     lb                 PRODUCE
# 34   each          FOOD - GROCERY
# 35     lb                 PRODUCE
# 36     lb                 PRODUCE
# 37     CT                 PRODUCE
# 38     lb                 PRODUCE
# 39     lb                 PRODUCE
# 40     lb                 PRODUCE
# 41     lb                 PRODUCE
# 42  fl oz  BAKING-RAW INGREDIENTS
# 43  fl oz  BAKING-RAW INGREDIENTS
# 44     Kg                 PRODUCE
# 45     lb                 PRODUCE
# 46     CT                 PRODUCE
# 47     CT                   BREAD
# 48      L                   DAIRY
# 49     oz                 PRODUCE
# 50      g          FOOD - GROCERY
# 51     lb          FOOD - GROCERY
# 52      g                  SPICES
# 53      L          FOOD - GROCERY
# 54      L          FOOD - GROCERY
# 55      L          FOOD - GROCERY
# 56     lb                 PRODUCE
# 57     lb                 PRODUCE
# 58     CT                 PRODUCE
# 59  BUNCH                 PRODUCE
# 60     lb                 PRODUCE
# 61     lb                 PRODUCE
# 62     Kg          FOOD - GROCERY
# 63     lb                 PRODUCE
# 64     Kg                  SPICES
# 65     Kg                  SPICES
# 66      g                  SPICES
# 67     lb                 PRODUCE
# 68     ea          FOOD - GROCERY
# 69     CT                 PRODUCE
# 70     oz          FOOD - GROCERY
# 71  BUNCH                 PRODUCE
# 72      g          FOOD - GROCERY
# 73      g                  SPICES
# 74     Kg                  SPICES
# 75  fl oz          FOOD - GROCERY
# 76      L          FOOD - GROCERY
# 77      L          FOOD - GROCERY
# 78     oz                  SPICES
# 79     lb                 SEAFOOD
# 80      L         PRODUCTION FOOD
# 81      L         PRODUCTION FOOD
# 82      L                   DAIRY
# 83     lb                 PRODUCE
# 84     lb                 PRODUCE
# 85     lb                  SPICES
# 86     lb          FOOD - GROCERY
# 87     Kg          FOOD - GROCERY
# 88      L          FOOD - GROCERY
# 89     lb                 PRODUCE
# 90     ea          FOOD - GROCERY
# 91      L                BEVERAGE
# 92     ea          FOOD - GROCERY

# %%
# creates a new array with unique ItemIds
all_id_list = Items["ItemId"].unique()

# %%
# None of the items are egg yolk liq
Items.loc[Items["Description"] == "Egg Yolk Liq"]
# Out:
# Empty DataFrame
# Columns: [ItemId, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup]
# Index: []

# %%
# Sumplemental option for egg, vegan option
Items.loc[Items["ItemId"] == "I-68700"]
# Out:
# Empty DataFrame
# Columns: [ItemId, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup]
# Index: []

# %%
# Gives you the list of breads
breadlist = []


# If the items in the Items list is a "LOAF", "SANDWICH", or "BREAD" then we should add it in the breadlist
# We append it onto the breadlist at position row["ItemId"]
for ind, row in Items.iterrows():
    if ("LOAF" or "SANDWICH" "BREAD") in row["Description"]:
        breadlist.append(row["ItemId"])

breadlist
# Out:
# ['I-13004']

# %%
# Based on info below there are 486 rows and 7 columns
Items.shape
# Out:
# (93, 7)

# %%
Items.dtypes
# Out:
# ItemId            object
# Description       object
# CaseQty           object
# CaseUOM           object
# PakQty            object
# PakUOM            object
# InventoryGroup    object
# dtype: object

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "Items_List.csv")
Items.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Import Ingredients List

# %%
# Read ingredients.xml files in the filepath_list and construct a dataframe
IngredientId = []
Conversion = []
InvFactor = []
Qty = []
Recipe = []
Uom = []

# Using the Ingredients XML file, we extract attributes containing ingredients, conversion, invFactor, qty, recipe, and uom. 
# Then we append it onto the IngredientId, Coversion, InvFactor, Qty, Recipe, and Uom lists
# Then we create a dataframe using the lists created. 

for filepath in filepath_list:
    path = filepath + '/Ingredients.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for x in xtree.iterfind('Ingredient'):
            IngredientId.append(x.attrib['ingredient'])
            Conversion.append(x.attrib['conversion'])
            InvFactor.append(x.attrib['invFactor'])
            Qty.append(x.attrib['qty'])
            Recipe.append(x.attrib['recipe'])
            Uom.append(x.attrib['uom'])
    
Ingredients = pd.DataFrame({'IngredientId': IngredientId, 'Qty': Qty,'Uom': Uom, 'Conversion': Conversion, 
                      'InvFactor': InvFactor,'Recipe': Recipe}).drop_duplicates()
Ingredients.drop_duplicates(subset=["IngredientId", "Recipe"], inplace=True)

Ingredients.reset_index(drop=True, inplace=True)

# %%
Ingredients
# Out:
#     IngredientId       Qty    Uom     Conversion  InvFactor   Recipe
# 0         I-4598     1.000     CT     1.00000000     0.0013  P-12954
# 1         I-3619     5.000      g     1.00000000     0.5000  P-14161
# 2         I-3649    10.000      g     1.00000000     1.0000  P-14161
# 3         I-3992     5.000     Kg     1.00000000     0.5000  P-14161
# 4         I-4589   907.184      g     0.00220462    90.7184  P-14161
# 5         I-4599     1.000   HEAD     1.00000000     0.1000  P-14161
# 6         I-4742   907.184      g     0.00220462    90.7184  P-14161
# 7         I-4919    56.699      g     0.00220462     5.6699  P-14161
# 199      P-44505   320.000     ml     0.00100000     1.0000  R-44511
# 200      P-44506     0.500   each     1.00000000     1.0000  R-44511
# 201      P-44510     3.000      g     1.00000000     1.0000  R-44511
# 202       I-4617     1.000      g     0.00220462     1.0000  R-46574
# 203      P-43707    15.000     ml     0.00100000     1.0000  R-46574
# 204      P-46570     8.000  fl oz     0.02840000     1.0000  R-46574
# 205      P-46572     5.000     ml     0.00100000     1.0000  R-46574
# 206      R-35269     1.000     ea     1.00000000     1.0000  R-47565
# 207      I-17594    60.000      g     0.00220462     1.0000  R-50482
# 208      I-43562    20.000      g     0.00220462     1.0000  R-50482
# 209       I-4574    20.000      g     0.00220462     1.0000  R-50482
# 210       I-4679     5.000      g     0.06666667     1.0000  R-50482
# 211      I-47530     7.000     ea     1.00000000     1.0000  R-50482
# 212      P-43680     5.000      g     1.00000000     1.0000  R-50482
# 213      P-50480   250.000     ml     0.00100000     1.0000  R-50482
# 214      P-50651    50.000      g     0.00100000     1.0000  R-50482
# 215      R-35651     1.000     ea     1.00000000     1.0000  R-60558
# 216      R-60569     1.000     ea     1.00000000     1.0000  R-60558
# 217      I-14181     2.000  slice     1.00000000     1.0000  R-60569
# 218      I-17617     2.000  slice     1.00000000     1.0000  R-60569
# 219      P-26077    45.000      g     0.00100000     1.0000  R-60569
# 220      P-34084    30.000      g     1.00000000     1.0000  R-60569
# 221      P-50809     2.000  slice     1.00000000     1.0000  R-60569
# 222      P-56398    45.000      g     0.00100000     1.0000  R-60569

# %%
# .loc attribute is used to filter rows and columns in a DataFrame based on if IngredientId is equal to I-29389

# This information tells us whether or not multiple recipes are using the same ingredient or not. Here we can see that 
# there are 3 recipes that use the same ingredient
Ingredients.loc[Ingredients["IngredientId"] == "I-29389"]
# Out:
# Empty DataFrame
# Columns: [IngredientId, Qty, Uom, Conversion, InvFactor, Recipe]
# Index: []

# %%
# Create a new dataframe that takes the IngredientId and Recipe column from the Ingredients dataframe

Ingredients_sample = Ingredients[["IngredientId", "Recipe"]]
Ingredients_sample
# Out:
#     IngredientId   Recipe
# 0         I-4598  P-12954
# 1         I-3619  P-14161
# 2         I-3649  P-14161
# 3         I-3992  P-14161
# 4         I-4589  P-14161
# 5         I-4599  P-14161
# 6         I-4742  P-14161
# 7         I-4919  P-14161
# 8         I-5983  P-14161
# 9         I-3643  P-18907
# 10        I-6026  P-18907
# 11        I-4381  P-24452
# 12       P-26514  P-24750
# 13        I-3388  P-26020
# 14        I-4657  P-26020
# 15       I-11185  P-26021
# 16        I-5983  P-26021
# 17        I-1813  P-26077
# 18        I-8060  P-26077
# 19       P-18907  P-26077
# 20       P-26020  P-26077
# 21       P-44896  P-26077
# 22       I-11215  P-26100
# 23       I-11218  P-26100
# 24       I-17150  P-26100
# 25        I-3312  P-26100
# 26       I-34065  P-26100
# 27        I-5977  P-26100
# 28        I-5983  P-26100
# 29        I-9685  P-26100
# 30        I-3388  P-26381
# 31        I-3623  P-26381
# 32        I-4657  P-26381
# 33       I-15358  P-26393
# 64      I-4589
# 67      I-4787
# 68      I-4919
# 69     P-18907
# 72     I-11181
# 73      I-3992
# 74      I-4657
# 75      I-4660
# 76      I-4745
# 77      I-5983
# 80      I-4589
# 81      I-4598
# 82      I-3388
# 83     P-26020
# 87      I-5983
# 89      I-3677
# 90      I-4742
# 96      I-1813
# 98      I-4341
# 105    P-26100
# 106    I-11181
# 108     I-2217
# 112     I-4919
# 115    P-18907
# 116    P-26020
# 118    P-39167
# 119     I-1813
# 121     I-8060
# 124     I-3619
# 125     I-3992
# 126     I-4589
# 127     I-4745
# 128     I-4919
# 129     I-5983
# 131     I-4508
# 132     I-4933
# 139     I-5983
# 140     I-4589
# 141     I-3141
# 142     I-5983
# 147     I-6443
# 151     I-4787
# 152    P-39167
# 157     I-4657
# 159     I-4598
# 172     I-4472
# 173     I-4712
# 178     I-4509
# 184    P-62008
# 190     I-4509
# 191    P-26381
# 193    P-39057
# 194    P-51523
# 197     I-6443
# 198    P-26393
# 203    P-43707
# Name: IngredientId, dtype: object

# %%
# We can see from the printed items above that I-64877 does not appear because it does not get duplicated
Ingredients.loc[Ingredients["IngredientId"] == "I-64877"]
# Out:
# Empty DataFrame
# Columns: [IngredientId, Qty, Uom, Conversion, InvFactor, Recipe]
# Index: []

# %%
210 * 9.8315
# Out:
# 2064.6150000000002

# %%
Ingredients
# Out:
#     IngredientId       Qty    Uom     Conversion  InvFactor   Recipe
# 0         I-4598     1.000     CT     1.00000000     0.0013  P-12954
# 1         I-3619     5.000      g     1.00000000     0.5000  P-14161
# 2         I-3649    10.000      g     1.00000000     1.0000  P-14161
# 3         I-3992     5.000     Kg     1.00000000     0.5000  P-14161
# 4         I-4589   907.184      g     0.00220462    90.7184  P-14161
# 5         I-4599     1.000   HEAD     1.00000000     0.1000  P-14161
# 6         I-4742   907.184      g     0.00220462    90.7184  P-14161
# 7         I-4919    56.699      g     0.00220462     5.6699  P-14161
# 8         I-5983    12.000      L     1.00000000     1.2000  P-14161
# 9         I-3643   225.000      g     0.00100000     0.1837  P-18907
# 10        I-6026  1000.000      g     1.00000000     0.8163  P-18907
# 11        I-4381     1.000     lb     1.00000000     1.1111  P-24452
# 12       P-26514   500.000      g     1.00000000  1000.0000  P-24750
# 13        I-3388   750.000     ml     0.00100000   300.0000  P-26020
# 14        I-4657     2.270     Kg     2.20462000     0.9080  P-26020
# 15       I-11185     1.100     Kg    35.27399000     0.3333  P-26021
# 16        I-5983     2.200      L     1.00000000     0.6667  P-26021
# 17        I-1813   125.000     ml     0.03381406    55.1146  P-26077
# 18        I-8060     4.000     lb   453.59200000     1.7637  P-26077
# 19       P-18907    45.000      g     1.00000000    19.8413  P-26077
# 20       P-26020   335.000      g     0.00100000   147.7072  P-26077
# 21       P-44896    60.000      g     0.00100000    26.4550  P-26077
# 22       I-11215    50.000      g     0.00220462     0.8772  P-26100
# 23       I-11218   250.000      g     0.00220462     4.3860  P-26100
# 24       I-17150    20.000     lb     1.00000000     0.3509  P-26100
# 216      R-60569     1.000     ea     1.00000000     1.0000  R-60558
# 217      I-14181     2.000  slice     1.00000000     1.0000  R-60569
# 218      I-17617     2.000  slice     1.00000000     1.0000  R-60569
# 219      P-26077    45.000      g     0.00100000     1.0000  R-60569
# 220      P-34084    30.000      g     1.00000000     1.0000  R-60569
# 221      P-50809     2.000  slice     1.00000000     1.0000  R-60569
# 222      P-56398    45.000      g     0.00100000     1.0000  R-60569

# %%
Ingredients.loc[Ingredients["IngredientId"] == "I-64877"]
# Out:
# Empty DataFrame
# Columns: [IngredientId, Qty, Uom, Conversion, InvFactor, Recipe]
# Index: []

# %%
# Below we are checking if we can extract an entire recipe. So we can do .loc with the particular recipe id and then 
# print all the data points (ingredientId, Qty, Uom, Conversion, InvFactor) for that recipe. 
Ingredients.loc[Ingredients["Recipe"] == "R-68698"]
# Out:
# Empty DataFrame
# Columns: [IngredientId, Qty, Uom, Conversion, InvFactor, Recipe]
# Index: []

# %%
Items.loc[Items["ItemId"] == "I-68700"]
# Out:
# Empty DataFrame
# Columns: [ItemId, Description, CaseQty, CaseUOM, PakQty, PakUOM, InventoryGroup]
# Index: []

# %%
Ingredients.shape
# Out:
# (223, 6)

# %%
Ingredients.dtypes
# Out:
# IngredientId    object
# Qty             object
# Uom             object
# Conversion      object
# InvFactor       object
# Recipe          object
# dtype: object

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "Ingredients_List.csv")
Ingredients.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Import Preps List

# %%
# Read preps.xml files in the filepath_list and construct a dataframe
PrepId = []
Description = []
PakQty = []
PakUOM = []
InventoryGroup = []


# Here we do the same thing for the Preps XML file where we find the columns using attrib function and then append it onto
# the dataframe called Preps. 

for filepath in filepath_list:
    path = filepath + '/Preps.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for x in xtree.iterfind('Prep'):
            PrepId.append(x.attrib['id'])
            Description.append(x.findtext('Description'))
            PakQty.append(x.findtext('PakQty'))
            PakUOM.append(x.findtext('PakUOM'))
            InventoryGroup.append(x.findtext('InventoryGroup'))
    
Preps = pd.DataFrame({'PrepId': PrepId, 'Description': Description,
                  'PakQty': PakQty, 'PakUOM':PakUOM, 'InventoryGroup': InventoryGroup}).drop_duplicates()
preps_columns = Preps.columns
Preps.drop_duplicates(subset=["PrepId"], inplace=True)

Preps.reset_index(drop=True, inplace=True)

# %%
Preps
# Out:
#      PrepId                     Description    PakQty PakUOM  \
# 0   P-26393  BATCH|Crisp Tortilla Strips|OK     0.907     Kg
# 1   P-56398                 BATCH|Guacamole     2.750     Kg
# 2   P-35648             BATCH|Tomato Bisque     8.000      L
# 3   P-50651               BLANCHED|Bok Choy     5.000     Kg
# 4   P-35818         BROTH|Chicken Dumpling     40.000      L
# 5   P-26100                       BROTH|Pho    57.000      L
# 6   P-35318           BROTH|Vegetarian Miso    10.000      L
# 7   P-26077              BUTTER|Garlic|Good     2.268     Kg
# 8   P-50500                CHIFFONADE|Basil   190.000      g
# 9   P-24750                CHOPPED|Cilantro     0.500     Kg
# 10  P-34084                    COOKED|Bacon    20.000      g
# 11  P-51578      COOKED|Rice Noodle|Lai Fen     2.000     Kg
# 12  P-41094               DICED|Carrot|1/4"    11.170     Kg
# 13  P-41095               DICED|Celery|1/4"    13.608     Kg
# 14  P-39167         DICED|Yellow Onion|3/4"    11.010     Kg
# 15   P-7635      DRAINED|Turtle Black Beans     1.740     Kg
# 16  P-45010         FAT|Beef from Pho Broth     2.000     Kg
# 17  P-43680             FRIED|Crispy Garlic   200.000      g
# 18  P-51582                 JULIENNE|Carrot    10.500     Kg
# 19  P-18907                 MIX|Salt&Pepper  1225.000      g
# 20  P-26381                OIL|Garlic Chili     4.000      L
# 21   P-9722           PREP Celery Processed    49.500     lb
# 22   P-7444               PREP|Garlic Puree     4.000      L
# 23  P-44585                 PREP|Lime|WEDGE     8.000  piece
# 24  P-57227                   PREP|Mirepoix     4.000     Kg
# 25  P-14161              PREP|Stock|Chicken    10.000      L
# 26  P-53277                  PREP|Veg Stock    10.300      L
# 27  P-26020            PUREE|Garlic|Kg - FT     2.500     Kg
# 28  P-43707             SAUCE|Creme Fraiche     3.500      L
# 29  P-44506          SLICED|Avocado|Quarter     4.000   each
# 30  P-39057           SLICED|Green Onion v1   150.000      g
# 31  P-45009                   SOUP|Beef Pho    16.500      L
# 32  P-31111                       SOUP|Miso    20.000      L
# 33  P-44505              SOUP|Tortillia|CAL    50.000      L
# 34  P-26021                  STEAMED|Quinoa     3.300     Kg
# 35  P-50480                   STOCK|Chicken    20.000      L
# 36  P-32661            STOCK|Veg from Conc.    31.100      L
# 37  P-46572           VEG|Sage Brown Butter     1.500      L
# 38  P-46570              VEG|SOUP| Pumpkin     15.000      L
# 39  P-35268          VEG|Tortilla Soup Base     5.000      L
# 40  P-51523                  YIELD|Bak Choy    21.800     Kg
# 41  P-12954                    YIELD|Celery   750.000      g
# 42  P-48606     YIELD|Chicken Thigh|Stirfry     1.400     Kg
# 43  P-44510            YIELD|Cilantro|Bunch    50.000      g
# 44  P-26514             YIELD|Cilantro|Herb    55.000      g
# 45  P-50809        YIELD|Country Loaf|Slice    18.000  slice
# 46  P-44896              YIELD|Herb|Parsley     0.500     Kg
# 47  P-56811                  YIELD|Jalapeno     4.000     Kg
# 48  P-43718      YIELD|Pasta|Med Rice Stick     3.750     Kg
# 49   P-9854                    YIELD|Radish    19.051     Kg
# 50  P-62008          YIELD|Shimeji Mushroom   900.000      g
# 51  P-50781                YIELD|Thai Basil   200.000      g
# 52  P-50587               YIELD|Tomato Roma     9.000     Kg
# 53  P-24452              YIELD|Yellow Onion     0.900     lb
#
#          InventoryGroup
# 0                  PREP
# 1                  PREP
# 2                  PREP
# 3                  PREP
# 4                  PREP
# 5                  PREP
# 6                  PREP
# 7                  PREP
# 8
# 9
# 10                 PREP
# 11
# 12
# 13
# 14
# 15
# 16
# 17                 PREP
# 18                 PREP
# 19
# 20                 PREP
# 21
# 22                 PREP
# 23
# 24
# 25                 PREP
# 26
# 27                 PREP
# 28                 PREP
# 29
# 30                 PREP
# 31                 PREP
# 32                 PREP
# 33                 PREP
# 34                 PREP
# 35                 PREP
# 36  ZDONT USE OK - PREP
# 37
# 38
# 39                 PREP
# 40
# 41
# 42                 PREP
# 43
# 44
# 45
# 46
# 47
# 48                 PREP
# 49
# 50
# 51
# 52
# 53

# %%
# This tells us that there are not any duplicates in the Preps dataframe. There is a different process|ingredient pair for 
# all the recipes. 
check = Preps["PrepId"].duplicated().any()
print(check)
# Out:
# False

# %%
# There are 546 rows and 5 columns
Preps.shape
# Out:
# (54, 5)

# %%
# Here we see there is only one place P-50739 is used in the Preps
Preps.loc[Preps["PrepId"] == "P-50739"]
# Out:
# Empty DataFrame
# Columns: [PrepId, Description, PakQty, PakUOM, InventoryGroup]
# Index: []

# %%
Preps.dtypes
# Out:
# PrepId            object
# Description       object
# PakQty            object
# PakUOM            object
# InventoryGroup    object
# dtype: object

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "Preps_List.csv")
Preps.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Import Products List

# %%
# Read products.xml files in the filepath_list and construct a dataframe
ProdId = []
Description = []
SalesGroup = []

# From the XML file for products append the id into ProdId, description into Description, and SalesGroup into SalesGroup list.
# Make a dataframe out of the 3 lists
# Then also drop the duplicates in the Products dataframe

for filepath in filepath_list:
    path = filepath + '/Products.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for x in xtree.iterfind('Prod'):
            ProdId.append(x.attrib['id'])
            Description.append(x.findtext('Description'))
            SalesGroup.append(x.findtext('SalesGroup'))
        
Products = pd.DataFrame({'ProdId': ProdId, 'Description': Description, 'SalesGroup': SalesGroup})
Products.drop_duplicates(inplace=True)

Products.reset_index(drop=True, inplace=True)

# %%
Products
# Out:
#      ProdId                    Description                      SalesGroup
# 0   R-44511  FLX|CAL|Soup|Tortilla Chicken               OK - FLEX KITCHEN
# 1   R-28260              GLB|Soup|Beef Pho            OK - GLOBAL KITCHEN
# 2   R-35819      GLB|Soup|ChickenDumpling             OK - GLOBAL KITCHEN
# 3   R-50482            GLB|SOUP|Wor wonton                      OK - SOUP
# 4   R-31955                 SIDE|Soup|16oz                      OK - SOUP
# 5   R-37630                 SIDE|Soup|Miso                      OK - SOUP
# 6   R-47565                 SOUP|Tortilla   OK- VEGETARIAN KITCHEN FEATURE
# 7   R-60569  TRUCK|GrilledCheese|Bacon Avo           OK - FOOD TRUCK(Food)
# 8   R-60558   TRUCK|Grl Cheese & Tom Soup|           OK - FOOD TRUCK(Food)
# 9   R-35651              TRUCK|Tomato Soup           OK - FOOD TRUCK(Food)
# 10  R-35319        VEG|SOUP|Miso Dumpling   OK- VEGETARIAN KITCHEN FEATURE
# 11  R-35269             VEG|SOUP|Tortilla          OK - VEGETARIAN KITCHEN
# 12  R-46574    VEG|SOUP|UBC Farms Pumpkin          OK - VEGETARIAN KITCHEN

# %%
# Here we can see that there is only one R-56966 in the products 
Products.loc[Products["ProdId"] == "R-56966"]
# Out:
# Empty DataFrame
# Columns: [ProdId, Description, SalesGroup]
# Index: []

# %%
Products.dtypes
# Out:
# ProdId         object
# Description    object
# SalesGroup     object
# dtype: object

# %%
# Here we can see that there is only one R-68698 in the products 
Products.loc[Products["ProdId"] == "R-68698"]
# Out:
# Empty DataFrame
# Columns: [ProdId, Description, SalesGroup]
# Index: []

# %%
Products.shape
# Out:
# (13, 3)

# %%
Products.dtypes
# Out:
# ProdId         object
# Description    object
# SalesGroup     object
# dtype: object

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "Products_List.csv")
Products.to_csv(path, index = False, header = True)

# %% [markdown]
# ### Import Conversions List

# %%
# Read conventions.xml files in the filepath_list and construct a dataframe
ConversionId = []
Multiplier = []
ConvertFromQty = []
ConvertFromUom = []
ConvertToQty = []
ConvertToUom = []

# From the XML file for Conversions append the id into ConversionId, multiplier into Multiplier, ConvertFrom->qty into 
# ConvertFromQty,ConvertFrom->uom into ConvertFromUom, ConvertTo->qty into ConvertToQty and and ConvertTo->uom into the
# CovertToUom list. 
# Make a dataframe out of the 3 lists
# Then also drop the duplicates in the Products dataframe


for filepath in filepath_list:
    path = filepath + '/Conversions.xml'
    if os.path.isfile(path):
        xtree = et.parse(path)
        xroot = xtree.getroot()
        for x in xtree.iterfind('Conversion'):
            ConversionId.append(x.attrib['id'])
            Multiplier.append(x.attrib['multiplier'])
            ConvertFromQty.append(x.find('ConvertFrom').attrib['qty'])
            ConvertFromUom.append(x.find('ConvertFrom').attrib['uom'])
            ConvertToQty.append(x.find('ConvertTo').attrib['qty'])
            ConvertToUom.append(x.find('ConvertTo').attrib['uom'])
    
    
Conversions = pd.DataFrame({'ConversionId': ConversionId, 'Multiplier': Multiplier, 'ConvertFromQty': ConvertFromQty,
                           'ConvertFromUom': ConvertFromUom, 'ConvertToQty': ConvertToQty, 'ConvertToUom': ConvertToUom}
                          ).drop_duplicates()

Conversions.reset_index(drop=True, inplace=True)

# %%
# Here we can see for example that to convert 1.14 L to 1 L the multiplier is 0.877 since 1/1.14 = 0.877
Conversions
# Out:
#    ConversionId     Multiplier ConvertFromQty ConvertFromUom ConvertToQty  \
# 0                   1.00000000         1.0000            XXX       1.0000
# 1                   0.87719298         1.0000          1.14L       1.1400
# 2                   0.66666667         1.0000           1.5L       1.5000
# 3                   0.57142857         1.0000         1.75 L       1.7500
# 4                   0.50000000         1.0000             2L       2.0000
# 5                   0.25000000         1.0000             4L       4.0000
# 6                   0.08333333         1.0000           FOOT      12.0000
# 7                   0.06250000         1.0000            16L      16.0000
# 8                   0.05917160         1.0000         1/2LTR      16.9000
# 9                   0.03937008         1.0000          750ML      25.4000
# 10                  0.03333333         1.0000        KEG 30L      30.0000
# 11                  0.02597403         1.0000         1140ml      38.5000
# 12                  0.02500000         1.0000        full in      40.0000
# 13                  0.02000000         1.0000        KEG 50L      50.0000
# 14                  0.01706485         1.0000        KEG 59L      58.6000
# 15                  0.01666667         1.0000           HOUR      60.0000
# 16                  0.00200000         1.0000          500ML     500.0000
# 17                  0.00153846         1.0000          650ML     650.0000
# 18                  0.00151515         1.0000          660ML     660.0000
# 19                  0.00142857         1.0000          700ML     700.0000
# 20                  0.00140845         1.0000          710ml     710.0000
# 21                  0.00133333         1.0000          750ML     750.0000
# 22                  0.00059172         1.0000         keg50L    1690.0000
# 23                  0.00050403         1.0000         keg59L    1984.0000
# 24                  2.00000000         2.0000            cup       1.0000
# 25                  2.00000000         2.0000             pt       1.0000
# 26                  2.00000000         2.0000           Tbsp       1.0000
# 27                  3.00000000         3.0000            tsp       1.0000
# 28                  4.00000000         4.0000             qt       1.0000
# 29                  8.00000000         8.0000          fl oz       1.0000
# 30                 16.00000000        16.0000             oz       1.0000
# 31                 28.34950000        28.3495              g       1.0000
# 32                 29.57350000        29.5735             ml       1.0000
# 33                 35.21126761       100.0000          fl oz       2.8400
# 34               1000.00000000      1000.0000              g       1.0000
# 35               1000.00000000      1000.0000             mg       1.0000
# 36               1000.00000000      1000.0000             ml       1.0000
# 37       I-1813     0.03278689         1.0000          fl oz      30.5000
# 38       I-1813     0.00409836         1.0000            cup     244.0000
# 39       I-2217     0.06666667         1.0000           Tbsp      15.0000
# 40       I-2254     0.06666667         1.0000           Tbsp      15.0000
# 41       I-2254     0.00413223         1.0000            cup     242.0000
# 42       I-3141     1.40845070         1.4085             ml       1.0000
# 43       I-3149     0.00416667         1.0000            cup     240.0000
# 44       I-3387     1.00000000         1.0000              L       1.0000
# 45       I-3387     0.22222222         1.0000            tsp       4.5000
# 46       I-3387     0.07142857         1.0000           Tbsp      14.0000
# 47       I-3387     0.00458716         1.0000            cup     218.0000
# 48       I-3388     0.22222222         1.0000            tsp       4.5000
# 49       I-3388     0.07142857         1.0000           Tbsp      14.0000
# 50       I-3388     0.00458716         1.0000            cup     218.0000
# 51       I-3389     0.22222222         1.0000            tsp       4.5000
# 52       I-3389     0.07407407         1.0000           Tbsp      13.5000
# 53       I-3389     0.00462963         1.0000            cup     216.0000
# 54       I-3619     4.65616546         1.0000           leaf       0.2148
# 55       I-3623     0.55555556         1.0000            tsp       1.8000
# 56       I-3623     0.18867925         1.0000           Tbsp       5.3000
# 57       I-3628     0.47619048         1.0000            tsp       2.1000
# 58       I-3628     0.15384615         1.0000           Tbsp       6.5000
# 59       I-3630     0.16666667         1.0000           Tbsp       6.0000
# 60       I-3638     0.45454545         1.0000            tsp       2.2000
# 61       I-3638     0.14285714         1.0000           Tbsp       7.0000
# 62       I-3643     0.14492754         1.0000           Tbsp       6.9000
# 63       I-3649     0.34482759         1.0000            tsp       2.9000
# 64       I-4341     0.06250000         0.2500            cup       4.0000
# 65       I-4341     0.35714286         1.0000             CT       2.8000
# 66       I-4375     0.06666667         1.0000             CT      15.0000
# 67       I-4472     0.00735294         1.0000             CT     136.0000
# 68       I-4473     0.00735294         1.0000           HEAD     136.0000
# 69       I-4574     0.00909091         1.0000            cup     110.0000
# 70       I-4598     0.00125000         1.0000             CT     800.0000
# 71       I-4599     0.13333333         1.0000           Tbsp       7.5000
# 72       I-4599     0.00220264         1.0000           HEAD     454.0000
# 73       I-4679     0.06666667         1.0000          BUNCH      15.0000
# 74       I-4712     0.01492537         1.0000             CT      67.0000
# 75       I-4745     0.00666667         1.0000             ea     150.0000
# 76       I-4826     0.00250000         1.0000          BUNCH     400.0000
# 77       I-5977     0.38461538         1.0000            tsp       2.6000
# 78       I-5977     0.14285714         1.0000          piece       7.0000
# 79       I-5977     0.12820513         1.0000           Tbsp       7.8000
# 80       I-5983     0.03378378         1.0000          fl oz      29.6000
# 81       I-5983     0.00100000         1.0000              L    1000.0000
# 82       I-6443     0.03246753         1.0000          fl oz      30.8000
# 83       I-6443     0.00406504         1.0000            cup     246.0000
# 84       I-7710     0.00027533         1.0000             CT    3632.0000
# 85       I-8058     0.00408163         1.0000            cup     245.0000
# 86       I-8060     0.07042254         1.0000           Tbsp      14.2000
# 87       I-8060     0.00440529         1.0000            cup     227.0000
# 88      I-14181     0.07142857         1.0000          slice      14.0000
# 89      I-22026     0.21276596         1.0000            tsp       4.7000
# 90      I-22026     0.00106383         1.0000              L     940.0000
# 91      I-45114     0.03333333         0.5000          fl oz      15.0000
#
#    ConvertToUom
# 0             L
# 1             L
# 2             L
# 3             L
# 4             L
# 5             L
# 6          INCH
# 7             L
# 8         fl oz
# 9         fl oz
# 10            L
# 11        fl oz
# 12          PTN
# 13            L
# 14            L
# 15       MINUTE
# 16           ml
# 17           ml
# 18           ml
# 19           ml
# 20           ml
# 21           ml
# 22        fl oz
# 23        fl oz
# 24           pt
# 25           qt
# 26        fl oz
# 27         Tbsp
# 28          gal
# 29          cup
# 30           lb
# 31           oz
# 32        fl oz
# 33            L
# 34           Kg
# 35            g
# 36            L
# 37            g
# 38            g
# 39            g
# 40            g
# 41            g
# 42            g
# 43            g
# 44           Kg
# 45            g
# 46            g
# 47            g
# 48            g
# 49            g
# 50            g
# 51            g
# 52            g
# 53            g
# 54            g
# 55            g
# 56            g
# 57            g
# 58            g
# 59            g
# 60            g
# 61            g
# 62            g
# 63            g
# 64            g
# 65           oz
# 66            g
# 67            g
# 68            g
# 69            g
# 70            g
# 71            g
# 72            g
# 73            g
# 74            g
# 75            g
# 76            g
# 77            g
# 78            g
# 79            g
# 80            g
# 81            g
# 82            g
# 83            g
# 84            g
# 85            g
# 86            g
# 87            g
# 88            g
# 89            g
# 90            g
# 91            g

# %%
# Here we can check that there are no ingredients listed since 
Conversions.loc[Conversions["ConversionId"] == "I-4582"]
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
all_id_list = Items["ItemId"].unique()
all_conv_list = Conversions["ConversionId"].unique()

print("All unique IDs list\n")
print(all_id_list)
print("\n")
print("All unique Conversions list\n")
print(all_conv_list)
# Out:
# All unique IDs list
#
# ['I-11181' 'I-4473' 'I-4472' 'I-4973' 'I-27410' 'I-4495' 'I-4491' 'I-3141'
#  'I-3619' 'I-3149' 'I-34065' 'I-17671' 'I-8060' 'I-4589' 'I-4574' 'I-4598'
#  'I-4599' 'I-14181' 'I-17617' 'I-3992' 'I-19665' 'I-37477' 'I-3623'
#  'I-5977' 'I-3627' 'I-11215' 'I-3628' 'I-4978' 'I-2217' 'I-3630' 'I-4657'
#  'I-51440' 'I-9685' 'I-4660' 'I-29665' 'I-4508' 'I-4617' 'I-4341' 'I-4695'
#  'I-4848' 'I-4918' 'I-4919' 'I-1813' 'I-6443' 'I-17932' 'I-4703' 'I-4712'
#  'I-13004' 'I-8058' 'I-8340' 'I-35793' 'I-19295' 'I-3638' 'I-3387'
#  'I-3388' 'I-3389' 'I-4745' 'I-4742' 'I-4375' 'I-4679' 'I-17150' 'I-4381'
#  'I-3431' 'I-43562' 'I-3643' 'I-11172' 'I-3649' 'I-4787' 'I-8374' 'I-7710'
#  'I-11185' 'I-4826' 'I-3099' 'I-6026' 'I-12176' 'I-45114' 'I-47774'
#  'I-22026' 'I-3312' 'I-17594' 'I-29357' 'I-29356' 'I-2254' 'I-4509'
#  'I-13228' 'I-11218' 'I-35336' 'I-7388' 'I-3677' 'I-4933' 'I-15358'
#  'I-5983' 'I-47530']
#
#
# All unique Conversions list
#
# ['' 'I-1813' 'I-2217' 'I-2254' 'I-3141' 'I-3149' 'I-3387' 'I-3388'
#  'I-3389' 'I-3619' 'I-3623' 'I-3628' 'I-3630' 'I-3638' 'I-3643' 'I-3649'
#  'I-4341' 'I-4375' 'I-4472' 'I-4473' 'I-4574' 'I-4598' 'I-4599' 'I-4679'
#  'I-4712' 'I-4745' 'I-4826' 'I-5977' 'I-5983' 'I-6443' 'I-7710' 'I-8058'
#  'I-8060' 'I-14181' 'I-22026' 'I-45114']

# %%
# Here we have the number of items in the list that are a part of the "all_id_list" but not part of the "all_conv_list"
missing_conv_id = []

for item in all_id_list:
    if item not in all_conv_list:
        missing_conv_id.append(item)
        
missing_conv_id
print(len(missing_conv_id))
# Out:
# 58

# %%
Conversions.shape
# Out:
# (92, 6)

# %%
Conversions.loc[Conversions["ConversionId"] == "I-29389"]
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
Conversions.dtypes
# Out:
# ConversionId      object
# Multiplier        object
# ConvertFromQty    object
# ConvertFromUom    object
# ConvertToQty      object
# ConvertToUom      object
# dtype: object

# %%
# Save the dataframe to csv
path = os.path.join(os.getcwd(), "data", "preprocessed", "Conversions_List.csv")
Conversions.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Data Summary

# %%
# Summary of raw data imported for evaluation
# Here we have a summary of the number of items, preps, ingredients, products, conversions

datasum = pd.DataFrame([Items.shape, Preps.shape, Ingredients.shape, Products.shape, Conversions.shape],
                       columns = ['count', 'columns'], 
                       index = ['Items', 'Preps', 'Ingredients', 'Products', 'Conversions'])
datasum
# Out:
#              count  columns
# Items           93        7
# Preps           54        5
# Ingredients    223        6
# Products        13        3
# Conversions     92        6
